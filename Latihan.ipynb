# %%
#I Wayan Agus Ari Kumara W. P. (170010090)
import argparse
import getpass
import imaplib
import poplib
import smtplib

# %%
IMAP_SERVER = 'outlook.office365.com'
IMAP_PORT = 993
POP_SERVER = 'outlook.office365.com'
POP_PORT = 995

def imap_mail(username): 
    mailbox = imaplib.IMAP4_SSL(IMAP_SERVER, IMAP_PORT) 
    password = getpass.getpass(prompt='Enter your email password: ') 
    mailbox.login(username, password)
    mailbox.select('Inbox')
    typ, data = mailbox.search(None, 'ALL')
    for num in data[0].split():
        typ, data = mailbox.fetch(num, '(RFC822)')
        print ('Message %s\n%s\n' % (num, data[0][1]))
        break
    mailbox.close()
    mailbox.logout()
    
def pop_mail(username): 
    mailbox = poplib.POP3_SSL(POP_SERVER, POP_PORT) 
    mailbox.user(username)
    password = getpass.getpass(prompt='Enter your email password: ') 
    mailbox.pass_(password) 
    num_messages = len(mailbox.list()[1])
    print ('Total emails: {}'.format(num_messages))
    mailbox.quit()

# %% [markdown]
# Buatlah sebuah fungsi yang dapat menggabungkan fungsionalitas fungsi `imap_mail()` dan `pop_mail()`

# %%
def mail(username, protocol, host, port):
    # Tulis kode program dari sini
        imap_mail("170010090@stikom-bali.ac.id")
        pop_mail("170010090@stikom-bali.ac.id")

# %% [markdown]
# Panggil fungsi `mail()` di bawah ini:

# %%
if __name__ == '__main__':
    mail("username","","","")
# Out:
# Enter your email password: ········
# Message b'1'
# b'Received: from TYAPR06MB2093.apcprd06.prod.outlook.com\r\n (2603:1096:404:8000::25) by TY2PR06MB3070.apcprd06.prod.outlook.com with\r\n HTTPS via TY2PR0101CA0039.APCPRD01.PROD.EXCHANGELABS.COM; Thu, 19 Mar 2020\r\n 10:30:06 +0000\r\nARC-Seal: i=2; a=rsa-sha256; s=arcselector9901; d=microsoft.com; cv=pass;\r\n b=\r\nARC-Message-Signature: i=2; a=rsa-sha256; c=relaxed/relaxed; d=microsoft.com;\r\n s=arcselector9901;\r\n h=From:Date:Subject:Message-ID:Content-Type:MIME-Version:X-MS-Exchange-SenderADCheck;\r\n bh=b3Tqz2vss3Dvv4Jz42xHnG5Czd/o1ffSvqC0ndyyu3Y=;\r\n b=\r\nARC-Authentication-Results: i=2; mx.microsoft.com 1; spf=pass (sender ip is\r\n 40.107.244.63) smtp.rcpttodomain=stikom-bali.ac.id\r\n smtp.mailfrom=email.teams.microsoft.com; dmarc=pass (p=reject sp=reject\r\n pct=100) action=none header.from=email.teams.microsoft.com; dkim=pass\r\n (signature was verified) header.d=email.teams.microsoft.com; arc=pass (0\r\n oda=1 ltdi=1 spf=[1,1,smtp.mailfrom=email.teams.microsoft.com]\r\n dmarc=[1,1,header.from=email.teams.microsoft.com])\r\nReceived: from OSAPR01CA0342.jpnprd01.prod.outlook.com (2603:1096:604:51::18)\r\n by TYAPR06MB2093.apcprd06.prod.outlook.com (2603:1096:404:1a::22) with\r\n Microsoft SMTP Server (version=TLS1_2,\r\n cipher=TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384) id 15.20.2814.22; Thu, 19 Mar\r\n 2020 10:30:03 +0000\r\nReceived: from PU1APC01FT041.eop-APC01.prod.protection.outlook.com\r\n (2603:1096:604:51:cafe::81) by OSAPR01CA0342.outlook.office365.com\r\n (2603:1096:604:51::18) with Microsoft SMTP Server (version=TLS1_2,\r\n cipher=TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384) id 15.20.2835.19 via Frontend\r\n Transport; Thu, 19 Mar 2020 10:30:03 +0000\r\nAuthentication-Results: spf=pass (sender IP is 40.107.244.63)\r\n smtp.mailfrom=email.teams.microsoft.com; stikom-bali.ac.id; dkim=pass\r\n (signature was verified)\r\n header.d=email.teams.microsoft.com;stikom-bali.ac.id; dmarc=pass action=none\r\n header.from=email.teams.microsoft.com;compauth=pass reason=100\r\nReceived-SPF: Pass (protection.outlook.com: domain of\r\n email.teams.microsoft.com designates 40.107.244.63 as permitted sender)\r\n receiver=protection.outlook.com; client-ip=40.107.244.63;\r\n helo=NAM12-MW2-obe.outbound.protection.outlook.com;\r\nReceived: from NAM12-MW2-obe.outbound.protection.outlook.com (40.107.244.63)\r\n by PU1APC01FT041.mail.protection.outlook.com (10.152.253.108) with Microsoft\r\n SMTP Server (version=TLS1_2, cipher=TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384) id\r\n 15.20.2814.13 via Frontend Transport; Thu, 19 Mar 2020 10:30:01 +0000\r\nARC-Seal: i=1; a=rsa-sha256; s=arcselector9901; d=microsoft.com; cv=none;\r\n b=\r\nARC-Message-Signature: i=1; a=rsa-sha256; c=relaxed/relaxed; d=microsoft.com;\r\n s=arcselector9901;\r\n h=From:Date:Subject:Message-ID:Content-Type:MIME-Version:X-MS-Exchange-SenderADCheck;\r\n bh=b3Tqz2vss3Dvv4Jz42xHnG5Czd/o1ffSvqC0ndyyu3Y=;\r\n b=KXouRKYOhLokJjBUa/3pexcy+SRW8r6cK5i+p0hxS4NBOEqKj9Bp ...
# Enter your email password: ········
# Total emails: 10
